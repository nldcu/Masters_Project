# %%
import pandas as pd

# %%
ref_ref_data = pd.read_csv("/Users/niall/Documents/Cypress_Code/Data/Multipath/multipath_data_test.csv",header=None)
ref_ref_data['Label'] = 1
ref_ref_data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  3.895949  1.041301  1.451234 -1.870216 -4.416225  0.120368  1.263571
# 1 -0.948959  0.213329  0.977819 -0.663076  0.540329  0.741871  3.304675
# 2 -0.486374 -0.241272 -2.682882  0.468271 -1.156260 -2.199973  2.871217
# 3 -0.312561 -0.481646  0.226875 -4.679536 -0.606569  0.571430  3.255990
# 4 -1.674838 -0.608310  2.012779 -0.648921 -1.792660 -3.290794  2.732783
#
#           7         8         9  ...        29        30        31        32  \
# 0 -1.980865  0.544944  0.478177  ...  0.149843  1.910252  0.875001  0.084611
# 1 -1.016243 -0.962062  0.130710  ... -1.412426  0.304016 -2.275173  0.059073
# 2 -2.372573 -1.713838  0.764716  ...  2.426290 -0.449349  1.253130  0.540717
# 3 -1.084721  1.206331  2.096823  ... -1.795280  1.231726 -1.987034 -0.310971
# 4 -0.826441 -3.582865  2.392318  ... -0.730917 -0.478840  1.843346  1.731042
#
#          33        34        35        36        37  Label
# ...

# %%
ref_ref_data.loc[10000:,'Label'] = 0

# %%
non_ref_data = pd.read_csv("/Users/niall/Documents/Cypress_Code/Data/Multipath/channel_3_multipath_data_non_ref_ref.csv",header=None)
non_ref_data['Label'] = 0
non_ref_data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.181828 -0.103814 -1.830222  2.142044 -1.367635 -1.434712 -1.594116
# 1  0.072744 -0.498591 -2.233785 -1.166063 -2.080267  1.626412 -0.218130
# 2 -0.775882 -1.348131  1.635620  1.615780 -2.399878  1.289463  1.342190
# 3  0.426477  2.187286  1.922735  0.167498  0.466763  2.656741 -2.070113
# 4  1.130784 -0.225079 -1.698315  0.716967  0.684028 -0.096237  0.453348
#
#           7         8         9  ...        29        30        31        32  \
# 0  0.821215  0.390048 -1.617316  ...  1.652689 -0.312044 -1.783078 -0.545015
# 1  0.457252  1.746959 -1.619308  ...  0.931833 -0.727636  1.490228  0.547797
# 2  0.246017 -1.343657  1.495023  ...  1.204663 -0.713091 -3.134738 -0.583504
# 3 -1.531735 -0.268769  2.168658  ... -0.547625 -0.282270 -1.589055 -0.001606
# 4  0.136393  0.726360 -0.389570  ...  2.385063  1.364032 -1.105691 -0.601228
#
#          33        34        35        36        37  Label
# ...

# %%
multipath_dataset = ref_ref_data.append(non_ref_data, ignore_index = True)

# %%
print(len(multipath_dataset))
# Out:
# 520000

# %%
ref_ref_data.to_csv('/Users/niall/Documents/Cypress_Code/Data/Multipath/multi_test_one.csv')
